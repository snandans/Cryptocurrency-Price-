# %%
#This python script gets the price of cryptocurrencies in real time

# %%
#Import the libraries
from bs4 import BeautifulSoup
import requests
import time

# %%
#Get the URL
url = "https://www.google.com/search?q=bitcoin+price"

#Make a request to the website
HTML = requests.get(url)

#Parse the HTML
soup = BeautifulSoup(HTML.text,"html.parser")

#Print soup to find where the text is that contains the price of cryptourrency
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    bitcoin price - Google Search
#   </title>
#   <script nonce="tWKU7MZJVCdrrtb48EbF1A==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#Create a function to get the price of cryptocurrency
def get_crypto_price(coin):
   #Get the URL
    url = "https://www.google.com/search?q="+coin+"+price"

    #Make a request to the website
    HTML = requests.get(url)

    #Parse the HTML
    soup = BeautifulSoup(HTML.text,"html.parser")

    #Find the current price
    text = soup.find('div',attrs={"class":"BNeawe iBp4i AP7Wnd"}).find('div',attrs={"class":"BNeawe iBp4i AP7Wnd"}).text
    
    #Return the text
    return text

# %%
#Get the price of a cryptocurrency
price = get_crypto_price("bitcoin")

#Print the price
print(price)
# Out:
# 31,21,022.37 Indian Rupee

# %%
#Create a function to consistently show the price of the cryptocurrency when it changes
def main():
    last_price = -1
    #Create a loop to continuously show the price 
    while True:
        #Choose the cryptocurrency whose price is desired
        crypt = "litecoin"
        #Get the price of cryptocurrency
        price = get_crypto_price(crypt)
        #check if the price changed
        if price != last_price:
            print(crypt +" price: ",price)
            last_price = price
        time.sleep(3)

# %%
#Run/Execute the main function
main()
# Out:
# litecoin price:  10,845.99 Indian Rupee
# litecoin price:  10,798.39 Indian Rupee
